# %%
x=y=z="same"
print(x)
print(y)
print(z)
# Out:
# same
# same
# same

# %%
january=march=may=july=august=october=december=31
april=june=september=november=30
february=28
print(january,february,march,april,may,june,july,august,september,october,november,december)
# Out:
# 31 28 31 30 31 30 31 31 30 31 30 31

# %%
thomas=33
marry=28
walter=None
isabella=46
print(thomas,marry,walter,isabella)
# Out:
# 33 28 None 46

# %%
website="apple.com"
print(website)
website="clarusway.com"
print(website)
# Out:
# apple.com
# clarusway.com

# %%
first_number=100
second_number=first_number
print(second_number)

# %%
x=15
y=33
z=x
x=y
print(x,y,z)
# Out:
# 33 33 15

# %%
x=5
print(x,"merhaba",11)
# Out:
# 5 merhaba 11

# %%
a,b,c=5,3.2,"hello"
print(a,b,c)
# Out:
# 5 3.2 hello

# %%
text="being a good person"
print(type(text))
# Out:
# <class 'str'>

# %%
my_float=40.0
negative_float=-18.66
print(my_float,negative_float,type(my_float),type(negative_float))
# Out:
# 40.0 -18.66 <class 'float'> <class 'float'>

# %%
true=True
print(true)
# Out:
# True

# %%
my_data ="5"
print(int(my_data))
# Out:
# 5

# %%
print(str(True))
# Out:
# True

# %%
pi=3.14
print(str(pi),type(str(pi)))
# Out:
# 3.14 <class 'str'>

# %%
pi=3.14
print(int(pi))
# Out:
# 3

# %%
no=3
print(float(no))
# Out:
# 3.0

# %%
a = "2.5"
print(float(a))
# Out:
# 2.5

# %%
x=39
v="11"
y="2.5"
z="I am at_"
print(x-int(v))
print(x-float(y))
print(z+str(x))
# Out:
# 28
# 36.5
# I am at_39

# %%
str(3)+"3"
# Out:
# '33'

# %%
3+int(3)
# Out:
# 6

# %%
3+float("3")
# Out:
# 6.0
