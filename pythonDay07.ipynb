# %%
print("{2} {3} {1} {0}".format("circumstances","in all","generosity","wins"))
# Out:
# generosity wins in all circumstances

# %%
print("{morality} {1} {0} {condition}".format("in all","wins",condition="circumstances",morality="generosity"))
print("{morality} {} {} {condition}".format("wins","in all",condition="circumstances",morality="generosity"))
# Out:
# generosity wins in all circumstances
# generosity wins in all circumstances

# %%
text ="If we had bought ${} crypto coins at the weekend, we would have had ${} with a profit share of {}% after {} days"
print(text.format(2000,"4,152.32",11,5))
# Out:
# If we had bought $2000 crypto coins at the weekend, we would have had $4,152.32 with a profit share of 11% after 5 days

# %%
capital = 2000
total="4,152.32"
rate=11
duration =5
text ="If we had bought ${} crypto coins at the weekend, we would have had ${} with a profit share of {}% after {} days"
print(text.format(capital,total,rate,duration))
# Out:
# If we had bought $2000 crypto coins at the weekend, we would have had $4,152.32 with a profit share of 11% after 5 days

# %%
capital = 2000
total="4,152.32"
rate=11
duration =5
text ="If we had bought ${} crypto coins at the weekend,\
we would have had ${}\
with a profit share of {}% after {} days"
print(text.format(capital,total,rate,duration))
# Out:
# If we had bought $2000 crypto coins at the weekend,we would have had $4,152.32with a profit share of 11% after 5 days

# %%
fruit="orange"
vegetable="tomato"
amount=6
print(f"The amount of {fruit} and {vegetable} we bought are totally {amount} pounds")
# Out:
# The amount of orange and tomato we bought are totally 6 pounds

# %%
sample=f"{2**3}"
print(sample)
# Out:
# 8

# %%
name="MARIAM"
print(f"My name is {name.capitalize()}")
# Out:
# My name is Mariam

# %%
name="Joseph"
job="teachers"
domain="Date Science"
message=(
    f"Hi {name},"
    f"You are one of the {job}"
    f"in the {domain} section."
)
print(message)
# Out:
# Hi Joseph,You are one of the teachersin the Date Science section.

# %%
name="Joseph"
job="teachers"
domain="Date Science"
message=(
    f"Hi {name},\n"
    f"You are one of the {job}\n"
    f"in the {domain} section."
)
print(message)
# Out:
# Hi Joseph,
# You are one of the teachers
# in the Date Science section.

# %%
name="susan"
age="young"
gender="lady"
school="CLRWY IT University"
text=f"{name.capitalize()} is a {age} {gender} and \
she is a student at the {school}."
print(text)
# Out:
# Susan is a young lady and she is a student at the CLRWY IT University.

# %%
name="susan"
age="young"
gender="lady"
school="CLRWY IT University"
text=(f"{name.capitalize()} is " 
f"a {age} {gender} and " 
f"she is a student at the {school}.")
print(text)
# Out:
# Susan is a young lady and she is a student at the CLRWY IT University.

# %%
text="Clarusway"
print(text.upper())
print(text)
# Out:
# CLARUSWAY
# Clarusway

# %%
text="www.clarusway.com"
print(text.endswith(".com"))
print(text.startswith("http"))
# Out:
# True
# False

# %%
text="www.clarusway.com"
print(text.endswith("cl",2,5))
print(text.startswith("cl",4,6))
# Out:
# False
# True

# %%
text="www.clarusway.com"
print(text.endswith("om",5))
print(text.startswith("cl",4))
# Out:
# True
# True

# %%
text="www.clarusway.com"
print(text.endswith(".co"))
print(text.startswith("w."))
# Out:
# False
# False
