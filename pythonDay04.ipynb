# %%
print(100+45)
print(500-65)
print(25*4)
print(10/2)
print(11//2)
print(5**3)
print(10%3)
# Out:
# 145
# 435
# 100
# 5.0
# 5
# 125
# 1

# %%
print(11-7)
print(4+11.0)
print("11-7")
#print("4"+4)
# Out:
# 4
# 15.0
# 11-7

# %%
import math
r=5
area=math.pi* r**2
print(area)
# Out:
# 78.53981633974483

# %%
print(11%2)
# Out:
# 1

# %%
print((4*5)/2)
# Out:
# 10.0

# %%
print(2**3)
print(3**2)
print((2*8)**0.5)
# Out:
# 8
# 9
# 4.0

# %%
a=0
a +=5
print(a)
a -=3
print(a)
a /=2
print(a)
a *=2
print(a)
a **=3
print(a)
a //=2
print(a)
a %=3
print(a)
# Out:
# 5
# 2
# 1.0
# 2.0
# 8.0
# 4.0
# 1.0

# %%
a=3
b=4
c=(a**2+b**2)**0.5
print(c)
# Out:
# 5.0

# %%
number=2020
text="we have reached"
print(text,number)
# Out:
# we have reached 2020

# %%
print("ahmet","mehmet","can")
# Out:
# ahmet mehmet can

# %%
print("ahmet","mehmet","can",sep="-")
# Out:
# ahmet-mehmet-can

# %%
print("ahmet","mehmet","can",sep="\n")
# Out:
# ahmet
# mehmet
# can

# %%
print("ahmet",end="-")
print("mehmet",end=" ")
print("can")
# Out:
# ahmet-mehmet can

# %%
print("clarusway",end="\n\n")
print("istanbul")
# Out:
# clarusway
#
# istanbul

# %%
print("\"")
# Out:
# "

# %%
print("\\")
# Out:
# \

# %%
print("3\\2=1.5")
# Out:
# 3\2=1.5

# %%
print("we are","\boosting","our","\brotherhood")
print('it \'s essential to learn Python\'s libraries in IT world.')
# Out:
# rotherhood
# it 's essential to learn Python's libraries in IT world.
