# %%
print("Hello World") # bu benim ilk commentim
# Out:
# Hello World

# %%
# print("Hello")
# print("merhaba")

# %%
print("I am a student")  # this is an inline comment
# this is a single line comment

# %%
print(5+6)  # bu 5 ile 6 sayısının toplamını veren kod'dur

# %%
x_ort=12.2
y_ort=0.6
# x ve y koordinatlarının ortalamasına ait cm cinsinden uzunluklar

# %%
uzunluk = 15  # burdaki 15 dalga boyunu temsil etmektedir

# %%
print(len.__doc__)
# Out:
# Return the number of items in a container.

# %%
print(print.__doc__)
# Out:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.

# %%
print(map.__doc__)
# Out:
# map(func, *iterables) --> map object
#
# Make an iterator that computes the function using arguments from
# each of the iterables.  Stops when the shortest iterable is exhausted.

# %%
print(sum.__doc__)
# Out:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.

# %%
print(input.__doc__)
# Out:
# Forward raw_input to frontends
#
#         Raises
#         ------
#         StdinNotImplentedError if active frontend doesn't support stdin.

# %%
x=11

# %%
print(x)
# Out:
# 11

# %%
x=22

# %%
print(x)
# Out:
# 22

# %%
name="clarusway"
year=2021
mood="sad"

# %%
print(name,year,mood)
# Out:
# clarusway 2021 sad

# %%
my_age=30
your_age=33
my_age=your_age

# %%
print(my_age)
# Out:
# 33

# %%
xx =11
yy=21
zz=15

# %%
xx=yy
zz=xx

# %%
print(xx)
print(yy)
print(zz)
# Out:
# 21
# 21
# 21

# %%
var_one=5
VAR = "Clarusway"

# %%
l = 0
I=0
time_0=2
time_O=3

# %%
x=1
X=2

# %%
print(x)
# Out:
# 1

# %%
true = 0
print(true)
# Out:
# 0
