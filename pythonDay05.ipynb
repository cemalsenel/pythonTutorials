# %%
True and False or not False or False
# Out:
# True

# %%
2 and 3
# Out:
# 3

# %%
2 or 3
# Out:
# 2

# %%
1 and  0
# Out:
# 0

# %%
0 or 1
# Out:
# 1

# %%
"" and 0 and  []
# Out:
# ''

# %%
3 and 2 and 1
# Out:
# 1

# %%
"" or 0 or []
# Out:
# []

# %%
1 or 2  or 3
# Out:
# 1

# %%
1 and bool("0")
# Out:
# True

# %%
1 and True
# Out:
# True

# %%
True and 1
# Out:
# 1

# %%
2 and "hello world"
# Out:
# 'hello world'

# %%
[] and "be happy"
# Out:
# []

# %%
print(None and ())
# Out:
# None

# %%
print(0 or 0j)
# Out:
# 0j

# %%
print(None or 1)
# Out:
# 1

# %%
2 or "hello world"
# Out:
# 2

# %%
[] or "be happy"
# Out:
# 'be happy'

# %%
print(None or ())
# Out:
# ()

# %%
{} or 0
# Out:
# 0

# %%
{0} or False
# Out:
# {0}

# %%
True or False and "False" and not "False" and 0
# Out:
# True

# %%
not ("None" or None) and False or ("and" and not ())
# Out:
# True

# %%
kadayif = True

#ic malzeme
findik = True
fistik=True
ceviz=False

#serbet
su = True
seker=False

yumurta=True

# %%
kadayif and (su and seker) and (findik or fistik or ceviz) and yumurta
# Out:
# False

# %%
"Clarus Way"[2:]
# Out:
# 'arus Way'

# %%
"Clarus Way"[2]
# Out:
# 'a'

# %%
name="Ali"

# %%
name[2]
# Out:
# 'i'

# %%
"clarus-way."[10]
# Out:
# '.'

# %%
"clarus-way."[5:]
# Out:
# 's-way.'

# %%
var = "clarus-way."

# %%
var[2:5]
# Out:
# 'aru'

# %%
var[::2]
# Out:
# 'cau-a.'

# %%
var[::-1]
# Out:
# '.yaw-suralc'

# %%
var[2:8:2]
# Out:
# 'au-'

# %%
var[8:2:-1]
# Out:
# 'aw-sur'

# %%
var[9:1:-2]
# Out:
# 'ywsr'

# %%
var[6:8]
# Out:
# '-w'

# %%
fruit="Orange"
print("word                     :",fruit)
print("first letter             :",fruit[0])
print("second letter            :",fruit[1])
print("from 3rd to 5th letters  :",fruit[2:5])
print("letter all after 3rd     :",fruit[2:])
print("letters until 5th letter :",fruit[:4])
# Out:
# word                     : Orange
# first letter             : O
# second letter            : r
# from 3rd to 5th letters  : ang
# letter all after 3rd     : ange
# letters until 5th letter : Oran
