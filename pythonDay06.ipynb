# %%
city = "Phoenix"
print(city[1:])
print(city[:6])
print(city[::2])
print(city[1::2])
print(city[-3:])
print(city[::-1])
# Out:
# hoenix
# Phoeni
# Ponx
# hei
# nix
# xineohP

# %%
"orange"[-6]
# Out:
# 'o'

# %%
"orange"[0]
# Out:
# 'o'

# %%
"orange"[-5:-2]
# Out:
# 'ran'

# %%
"orange"[-2:-5:-1]
# Out:
# 'gna'

# %%
"orange"[4:1:-1]
# Out:
# 'gna'

# %%
animal="hippopotamus"
print(animal[1:])
print(animal[:6])
print(animal[::2])
print(animal[1:7:2])
print(animal[-3:])
print(animal[::-1])
# Out:
# ippopotamus
# hippop
# hpooau
# ipp
# mus
# sumatopoppih

# %%
vegetable="tomato"
len(vegetable)
# Out:
# 6

# %%
len("orange")
# Out:
# 6

# %%
str1="upper"
str2="case"
print(str1+str2)
print("upper"+"case")
print(* str1)
print(3*str1)
print("upper"*3)
# Out:
# uppercase
# uppercase
# u p p e r
# upperupperupper
# upperupperupper

# %%
str3="upper"
str3 *=3
str3 +="case"
print(str3)
# Out:
# upperupperuppercase

# %%
fruit = "orange"
vegetable="tomato"
amount=4
print("The amount of {0} we bought is {1} pounds".format(fruit,amount))
# Out:
# The amount of orange we bought is 4 pounds

# %%
print("{state} is the most {adjective} state of the {country}".format(state="california",country="USA",adjective="crowded"))
# Out:
# california is the most crowded state of the USA

# %%
state="california"
country="USA"
adjective="crowded"
print("{0} is the most {2} state of the {1}".format(state,country,adjective))
# Out:
# california is the most crowded state of the USA

# %%
print("{} is the most {adjective} state of the {country}".format("california",country="USA",adjective="crowded"))
print("{0} is the most {adjective} state of the {country}".format("california",country="USA",adjective="crowded"))
print("{} is the most {adjective} state of the {}".format("california","USA",adjective="crowded"))
# Out:
# california is the most crowded state of the USA
# california is the most crowded state of the USA
# california is the most crowded state of the USA

# %%
print("{}--{}".format("ahmet","mehmet"))
# Out:
# ahmet--mehmet

# %%
print("{x}-{}-{y}-{}".format("a","b",x="c",y="d"))
print("{y}-{1}-{x}-{0}".format("a","b",x="c",y="d"))
# Out:
# c-a-d-b
# d-b-c-a
