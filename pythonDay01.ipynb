# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(' . ')
# Out:
#  .

# %%
print("I'm feeling ok")
# Out:
# I'm feeling ok

# %%
print("Arkadaşım bana 'merhaba' dedi")
# Out:
# Arkadaşım bana 'merhaba' dedi

# %%
print("""Arkadaşım bana "merhaba" dedikten sonra 'bye' dedi.'""")
# Out:
# Arkadaşım bana "merhaba" dedikten sonra 'bye' dedi.'

# %%
print('3.14') # string
print(3.14) # integer
# Out:
# 3.14
# 3.14

# %%
print("print(3.14)")
# Out:
# print(3.14)

# %%
print("""1""""""1""")
# Out:
# 11

# %%
print(''''hello"''')
# Out:
# 'hello"

# %%
print('first line')
print()
print('''third line''')
# Out:
# first line
#
# third line

# %%
print()
print('')

# %%
print()
print('''')
# Out:
#   File "<ipython-input-14-1eeb94591c0c>", line 2
#     print('''')
#                ^
# SyntaxError: EOF while scanning triple-quoted string literal
